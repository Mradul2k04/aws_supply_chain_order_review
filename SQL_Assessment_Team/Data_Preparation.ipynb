# %% [markdown]
# ## Phase 1 – Data Preparation (Common Task)
# ### Task 1: Data Profiling

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\aws_supply_chain_order_review\SQL_Assessment_Team\dataset\aws_supply_chain_orders_raw.csv")
df.head()
# Out:
#    order_id warehouse region product  order_qty                  order_date  \
# 0  ORD-1000      WH-C   West  Router         42  2026-02-16 06:22:56.185879
# 1  ORD-1001      WH-A   West  Laptop         30  2026-02-25 06:22:56.185905
# 2  ORD-1002      WH-C  South  Switch         19  2026-03-13 06:22:56.185910
# 3  ORD-1003      WH-C  North  Server         17  2026-02-14 06:22:56.185913
# 4  ORD-1004      WH-A   East  Laptop         19  2026-02-18 06:22:56.185916
#
#                 delivery_date  delivery_time_days     status
# 0  2026-03-24 06:22:56.186200                 4.0    Pending
# 1  2026-03-15 06:22:56.186205                12.0    Pending
# 2  2026-03-13 06:22:56.186207                13.0    Pending
# 3  2026-03-01 06:22:56.186209                 9.0    Pending
# 4  2026-03-11 06:22:56.186211                 3.0  Delivered

# %% [markdown]
# ### total records

# %%
df.shape[0]
# Out:
# 155

# %% [markdown]
# ### total columns

# %%
df.shape[1]
# Out:
# 9

# %% [markdown]
# ### Missing Values

# %%
df.isnull().sum()
# Out:
# order_id               0
# warehouse              0
# region                 5
# product                0
# order_qty              0
# order_date             0
# delivery_date          0
# delivery_time_days    11
# status                 0
# dtype: int64

# %% [markdown]
# ### Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %% [markdown]
# ### Invalid Data Types

# %%
df.dtypes
# Out:
# order_id                  str
# warehouse                 str
# region                    str
# product                   str
# order_qty               int64
# order_date                str
# delivery_date             str
# delivery_time_days    float64
# status                    str
# dtype: object

# %%
df["order_date"] = pd.to_datetime(df["order_date"])

df["delivery_date"] = pd.to_datetime(df["delivery_date"])

# %%
df.dtypes
# Out:
# order_id                         str
# warehouse                        str
# region                           str
# product                          str
# order_qty                      int64
# order_date            datetime64[us]
# delivery_date         datetime64[us]
# delivery_time_days           float64
# status                           str
# dtype: object

# %% [markdown]
# ### Null percentage per Column

# %%
null_percentage = (df.isnull().sum() / len(df)) * 100
